# %% [markdown]
# # Assignment - 7

# %% [markdown]
# 1.What is the name of the feature responsible for generating Regex objects?

# %% [markdown]
# Ans : re.compile() is the feature responsible for generation of Regex objects

# %%
import re
x = re.compile("some_random_pattern")
type(x)
print(x)
# Out:
# re.compile('some_random_pattern')

# %% [markdown]
# 2.Why do raw strings often appear in Regex objects?

# %% [markdown]
# Ans : Regular expressions use the backslash character ('\') to indicate special forms (Metacharacters) or to allow special characters (special sequences) to be used without invoking their special meaning. this collides with Python's usage of the same character for the same purpose in string literals. Hence, Raw strings are used (ex. r"\n") sp that backslashes do not have to be escaped.

# %% [markdown]
# 3.What is the return value of the search() method?

# %% [markdown]
# Ans : The return value of re.search(pattern,string) method is a match object if the pattern is observed in the string else it returns a None

# %%
import re
match = re.search('i', 'Data Science', flags=re.IGNORECASE)
print('Output:' , match)
match = re.search('X' , 'Data Science' , flags = re.IGNORECASE)
print('Output:',match)
# Out:
# Output: <re.Match object; span=(7, 8), match='i'>
# Output: None

# %% [markdown]
# 4.From a Match item, how do you get the actual strings that match the pattern?

# %% [markdown]
# Ans : For Matched item group() methods returns actual string that match the pattern

# %%
import re
match = re.search('ineuron','Ineuron Assignment Work', flags=re.IGNORECASE)
print('Output:',match.group())
# Out:
# Output: Ineuron

# %% [markdown]
# 5.In the regex which created from the r&#39;(\d\d\d)-(\d\d\d-\d\d\d\d)&#39;, what does group zero cover?
# Group 2? Group 1?

# %% [markdown]
# Ans : in the Regex r'(\d\d\d)-(\d\d\d-\d\d\d\d)', the zero group covers the entire pattern match where as the first froup cover (\d\d\d) and the second group cover (\d\d\d-\d\d\d\d)

# %%
import re
phoneNumRegex = re.compile(r'(\d\d\d)-(\d\d\d-\d\d\d\d)')
mo = phoneNumRegex.search('My number is 123-456-6785.')
print(mo.group()) # print all group i tuple format
print(mo.group()) # Always returns the fully matched string 
print(mo.group(1)) # returns the first group
print(mo.group(2)) # returns the second group
# Out:
# 123-456-6785
# 123-456-6785
# 123
# 456-6785

# %% [markdown]
# 6.In standard expression syntax, parentheses and intervals have distinct meanings. How can you tell
# a regex that you want it to fit real parentheses and periods?

# %% [markdown]
# Ans : The \\. \(and \) escape characters in the raw string passed to re.compile() will match actual parenthesis characters.

# %%
import re
phoneNumRegex = re.compile(r'(\(\d\d\d\)) (\d\d\d-\d\d\d\d)')
mo = phoneNumRegex.search('My phone number is (271) 543-9889.')
print(mo.group())
# Out:
# (271) 543-9889

# %% [markdown]
# 7.The findall() method returns a string list or a list of string tuples. What causes it to return one of
# the two options?

# %% [markdown]
# Ans : if the regex pattern has no groups , a list of string matched id returned. if the regex pattern has groups , a list og tuple of strings is returned.

# %%
import re
phoneNumRegex = re.compile(r'(\(\d\d\d\)) (\d\d\d-\d\d\d\d)')
mo = phoneNumRegex.findall('My number is (271) 543-9889.')
print(mo)

import re
phoneNumRegex = re.compile(r'\d{3}-\d{3}-\d{4}')
mo = phoneNumRegex.findall('My number is 271-543-9889.')
print(mo)
# Out:
# [('(271)', '543-9889')]
# ['271-543-9889']

# %% [markdown]
# 8.In standard expressions, what does the | character mean?

# %% [markdown]
# Ans : in standard expressions | means OR operator.

# %% [markdown]
# 9. In regular expressions, what does the character stand for?

# %% [markdown]
# Ans : In regular Expression, ? characters represents zero one match of the preceeding group.

# %%
import re
match_1 = re.search("Bat(wo)?man","Batman returns")
print(match_1)
match_2 = re.search("Bat(wo)?man","Batman returns")
print(match_2)
# Out:
# <re.Match object; span=(0, 6), match='Batman'>
# <re.Match object; span=(0, 6), match='Batman'>

# %% [markdown]
# 10.In regular expressions, what is the difference between the + and * characters?

# %% [markdown]
# Ans : In Regular Expressions, * Represents Zero ore more occurances of the preceeding group, whereas + represents one or more occurances of the preceeding group.

# %%
import re
match_1 = re.search("Bat(wo)*man","Batman returns")
print(match_1)
match_2 = re.search("Bat(wo)+man","Batman returns")
print(match_2)
# Out:
# <re.Match object; span=(0, 6), match='Batman'>
# None

# %% [markdown]
# 11.What is the difference between {4} and {4,5} in regular expression?

# %% [markdown]
# Ans : {4} means that its preceeding group repeat 4 times. where as {4,5} means that its preceeding should repeat minimum 4 times and maximum 5 times inclusively

# %%
import re
haRegex = re.compile(r'(Yes){3}')
p1 = haRegex.search('YesYesYes')
p2 = haRegex.search('Yes')
print(p1.group())
print(p2)
# Out:
# YesYesYes
# None

# %% [markdown]
# 12.What do you mean by the \d, \w, and \s shorthand character classes signify in regular
# expressions?

# %% [markdown]
# Ans : \d, \w and \s are special sequences in regular expressions in python:
#
# 1. \w - Matches a word character equivalent to [a-zA-Z0-9 ]
# 2. \d - Matches digit character equivalent to [0-9]
# 3. \s - Matches whitespace character (space, tab, newline, etc)

# %% [markdown]
# 13.What do means by \D, \W, and \S shorthand character classes signify in regular expressions?

# %% [markdown]
# Ans :  \D, \W and \S are special sequences in regular expressions in python:
#
# 1. \D - Matches any non-digit character, this is equivalent to the set class [^0-9]
# 2. \W - Matches any non-alpanumeric character equivalent to [^a-zA-Z0-9]
# 3. \S - Matches any non-whitespace character

# %% [markdown]
# 14.What is the difference between .*? and .*?

# %% [markdown]
# Ans : .* is a greedy mode, which returns the longest string that meets the condition. whereas .*? is a non greedy mode which reutrns vthe shortest string that meets the condition.

# %% [markdown]
# 15.What is the syntax for matching both numbers and lowercase letters with a character class?

# %% [markdown]
# Ans : The syntax is either [a-z0-9] or [0-9a-z]

# %% [markdown]
# 16. What is the procedure for making a normal expression in regax case insensitive?

# %% [markdown]
#  We can pass re.IGNORECASE as a flag to make a normal expression case insensitive

# %% [markdown]
# 17.What does the . character normally match? What does it match if re.DOTALL is passed as 2nd
# argument in re.compile()?

# %% [markdown]
# Ans : Dot . character matches everyting in input except newline character . , by passing re.DOTALL as a flag to re.compile(),you can make the dot character match all characters, including the newline character.

# %% [markdown]
# 18. If numReg = re.compile(r&#39;\d+&#39;), what will numRegex.sub(&#39;X&#39;, &#39;11 drummers, 10 pipers, five rings, 4
# hen&#39;) return?

# %%
#Ans :
import re 
numReg = re.compile(r'\d+')
numReg.sub('X', '11 drummers, 10 pipers, five rings, 4 hen')
# Out:
# 'X drummers, X pipers, five rings, X hen'

# %% [markdown]
# 19.What does passing re.VERBOSE as the 2nd argument to re.compile() allow to do?

# %% [markdown]
# Ans: re.VERBOSE will allow to add whitespace and comments to string passed to re.compile().

# %%
regex_email = re.compile(r'^([a-z0-9_\.-]+)@([0-9a-z\.-]+)\.([a-z\.]{2,6})$',re.IGNORECASE)
regex_email = re.compile(r""" 
                            ^([a-z0-9_\.-]+)                      # local part 
                            @                                     # single @ sign
                            ([0-9a-z\.-]+)                        # Domain name
                            \.                                    # single dot .
                            ([a-z]{2,6})$                         # top level 
                            """,re.VERBOSE | re.IGNORECASE)

# %% [markdown]
# 21.How would you write a regex that matches the full name of someone whose last name isWatanabe? You can assume that the first name that comes before it will always be one word thatbegins with a capital letter. The regex must match the following:
#
# &#39;Haruto Watanabe&#39;
#
#
# &#39;Alice Watanabe&#39;
#
# &#39;RoboCop Watanabe&#39;
#
#
# but not the following:
#
# &#39;haruto Watanabe&#39; (where the first name is not capitalized)
#
#
# &#39;Mr. Watanabe&#39; (where the preceding word has a nonletter character)
# &#39;Watanabe&#39; (which has no first name)
#
# &#39;Haruto watanabe&#39; (where Watanabe is not capitalized)

# %% [markdown]
# Ans : pattern = r'[A-Z]{1}[a-z]*\sWatanbe'

# %%
import re 
pattern = r'[A-Z]{1}[a-z]*\sWatanbe'
namex = re.compile(pattern)
for name in ['Haruto Watanabe','Alice Watanabe','RoboCop Watanabe','haruto Watanabe','Mr. Watanabe','Haruto watanabe' ]:
    print('Output: ',name,'->',namex.search(name))
# Out:
# Output:  Haruto Watanabe -> None
# Output:  Alice Watanabe -> None
# Output:  RoboCop Watanabe -> None
# Output:  haruto Watanabe -> None
# Output:  Mr. Watanabe -> None
# Output:  Haruto watanabe -> None

# %% [markdown]
# 22.How would you write a regex that matches a sentence where the first word is either Alice, Bob,
# or Carol; the second word is either eats, pets, or throws; the third word is apples, cats, or baseballs;
# and the sentence ends with a period? This regex should be case-insensitive. It must match the
# following:
# &#39;Alice eats apples.&#39;
#
# &#39;Bob pets cats.&#39;
#
# &#39;Carol throws baseballs.&#39;
#
# &#39;Alice throws Apples.&#39;
#
# &#39;BOB EATS CATS.&#39;
#
#
# but not the following:
#
#
# &#39;RoboCop eats apples.&#39;
#
# &#39;ALICE THROWS FOOTBALLS.&#39;
#
# &#39;Carol eats 7 cats.&#39;

# %%
import re
pattern = r'(Alice|Bob|Carol)\s(eats|pets|throws)\s(apples|cats|baseballs)\.'
casex = re.compile(pattern,re.IGNORECASE)
for ele in ['Alice eats apples.','Bob pets cats.','Carol throws baseballs.','Alice throws Apples.','BOB EATS CATS.','RoboCop eats apples.'
,'ALICE THROWS FOOTBALLS.','Carol eats 7 cats.']:
    print('Output: ',ele,'->',casex.search(ele))
# Out:
# Output:  Alice eats apples. -> <re.Match object; span=(0, 18), match='Alice eats apples.'>
# Output:  Bob pets cats. -> <re.Match object; span=(0, 14), match='Bob pets cats.'>
# Output:  Carol throws baseballs. -> <re.Match object; span=(0, 23), match='Carol throws baseballs.'>
# Output:  Alice throws Apples. -> <re.Match object; span=(0, 20), match='Alice throws Apples.'>
# Output:  BOB EATS CATS. -> <re.Match object; span=(0, 14), match='BOB EATS CATS.'>
# Output:  RoboCop eats apples. -> None
# Output:  ALICE THROWS FOOTBALLS. -> None
# Output:  Carol eats 7 cats. -> None
